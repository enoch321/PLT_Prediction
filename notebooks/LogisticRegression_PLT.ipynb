# %% [markdown]
# # LogisticRegression for PLT Reduction Prediction
#
# ## Task
# - Binary classification
# - Target: PLT reduction (0 = normal, 1 = reduced)
#
# ## Model
# - LogisticRegression Classifier (sklearn)
#
# ## Metrics
# - Accuracy
# - Precision
# - Recall
# - F1-score
# - ROC-AUC
# - PR-AUC
#
# ## Notes
# This notebook serves as the comparison model.

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    roc_curve,
    precision_recall_curve
)

plt.rcParams["figure.dpi"] = 120
sns.set_style("whitegrid")

# %%
RANDOM_STATE = 42
TEST_SIZE = 0.2

TARGET_COL = "PLT 减少事件分组"
DATA_PATH = "../data/PLTdataset.xlsx"
SHEET_NAME = "血小板减少预测"

# %%
df = pd.read_excel(DATA_PATH, sheet_name=SHEET_NAME)

print("Data shape:", df.shape)
df.head()
# Out:
# Data shape: (63, 36)
#   样本名称  PLT count(0,>100,1,<100)  PLT 减少事件分组  PLT 严重程度分组  Gender（女，0；男，1）  \
# 0   N1                     135.0         0.0         0.0              0.0
# 1  N10                     143.0         0.0         0.0              1.0
# 2  N11                     116.0         0.0         0.0              1.0
# 3  N12                     156.0         0.0         0.0              1.0
# 4  N13                     138.0         0.0         0.0              1.0
#
#    动脉血栓（有1，无0）  FHb(1,>40mg/L;0,<40mg/L)  FHb(1,>40mg/L;0,<40mg/L).1    LDH  \
# 0          0.0                 19.974734                         0.0  237.0
# 1          1.0                 20.367691                         0.0  273.0
# 2          1.0                 49.988801                         1.0  167.0
# 3          0.0                 14.744621                         0.0  216.0
# 4          0.0                 15.565815                         0.0  125.0
#
#    RDW1(0<15%,1≥15%  ...    WBC    NC   STO   FIB  D dimer    NO   CHO   LDL  \
# 0              13.7  ...   5.90  3.14  25.2  2.13     8.26  28.5  4.28  1.88
# 1              15.0  ...   5.50  3.50  18.0  2.30     0.39  49.0  3.17  1.39
# 2              15.2  ...  10.21  7.12   5.0  2.38    25.17  34.5  3.70  2.24
# 3              15.0  ...   4.21  2.98   5.0  2.30     0.66  30.0  7.82  3.94
# 4              14.7  ...   6.90  4.76   5.0  2.42     0.73  35.5  3.48  1.66
#
#    Pla(脂蛋白a)    SOD
# 0       0.55   72.0
# 1       0.10   45.0
# 2       0.10  101.0
# 3       0.31   90.0
# 4       0.15  133.0
#
# [5 rows x 36 columns]

# %%
df.info()

df[TARGET_COL].value_counts(normalize=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 36 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   样本名称                                       62 non-null     object
#  1   PLT count(0,>100,1,<100)                   62 non-null     float64
#  2   PLT 减少事件分组                                 62 non-null     float64
#  3   PLT 严重程度分组                                 62 non-null     float64
#  4   Gender（女，0；男，1）                            62 non-null     float64
#  5   动脉血栓（有1，无0）                                62 non-null     float64
#  6   FHb(1,>40mg/L;0,<40mg/L)                   62 non-null     float64
#  7   FHb(1,>40mg/L;0,<40mg/L).1                 62 non-null     float64
#  8   LDH                                        62 non-null     float64
#  9   RDW1(0<15%,1≥15%                           62 non-null     float64
#  10  RDW1(0<15%,1≥15%.1                         62 non-null     float64
#  11  TM(>5450,1;≤5450，0，正常范围5450±2140)pg/mL)    62 non-null     float64
#  12  TM(>5450,1;≤5450，0，正常范围5450±2140)pg/mL).1  62 non-null     float64
#  13  CRP                                        62 non-null     float64
#  14  脾大（1,是，0否）                                 62 non-null     float64
#  15  PLA2（0<659IU/L,1≥659IU/L）                  62 non-null     float64
#  16  PLA2（0<659IU/L,1≥659IU/L）.1                62 non-null     float64
#  17   HGB（1<100mg/L,0≥100mg/L）                  62 non-null     float64
#  18   HGB（1<100mg/L,2≥100mg/L）                  62 non-null     float64
#  19  MCV(0<100fL,1≥100mfL)                      63 non-null     float64
#  20  MCV(0<100fL,1≥100mfL).1                    62 non-null     float64
#  21  HDL（0≥0.8mmol/L,1<0.8mmol/L）               62 non-null     float64
#  22  HDL（0≥0.8mmol/L,1<0.8mmol/L）.1             62 non-null     float64
#  23  FVIII(0.<120;1,>120%)                      62 non-null     float64
#  24  FVIII(0.<120;1,>120%).1                    62 non-null     float64
#  25  Age                                        62 non-null     float64
#  26  WBC                                        62 non-null     float64
#  27  NC                                         62 non-null     float64
#  28  STO                                        62 non-null     float64
#  29  FIB                                        62 non-null     float64
#  30  D dimer                                    62 non-null     float64
#  31  NO                                         62 non-null     float64
#  32  CHO                                        62 non-null     float64
#  33  LDL                                        62 non-null     float64
#  34  Pla(脂蛋白a)                                  62 non-null     float64
#  35  SOD                                        62 non-null     float64
# dtypes: float64(35), object(1)
# memory usage: 17.8+ KB
# PLT 减少事件分组
# 0.0    0.516129
# 1.0    0.483871
# Name: proportion, dtype: float64

# %%
DROP_COLS = ["样本名称", "PLT count(0,>100,1,<100)", "PLT 严重程度分组", "Gender（女，0；男，1）", "动脉血栓（有1，无0）", TARGET_COL]
X = df.drop(columns=DROP_COLS)
y = df[TARGET_COL]

# %%
print("Missing values:")
print(X.isna().sum().sort_values(ascending=False))

X = X.dropna()
y = y.loc[X.index]

X = pd.get_dummies(X, drop_first=True)
print("Feature shape after encoding:", X.shape)
# Out:
# Missing values:
# FHb(1,>40mg/L;0,<40mg/L)                     1
# FHb(1,>40mg/L;0,<40mg/L).1                   1
# Pla(脂蛋白a)                                    1
# LDL                                          1
# CHO                                          1
# NO                                           1
# D dimer                                      1
# FIB                                          1
# STO                                          1
# NC                                           1
# WBC                                          1
# Age                                          1
# FVIII(0.<120;1,>120%).1                      1
# FVIII(0.<120;1,>120%)                        1
# HDL（0≥0.8mmol/L,1<0.8mmol/L）.1               1
# HDL（0≥0.8mmol/L,1<0.8mmol/L）                 1
# MCV(0<100fL,1≥100mfL).1                      1
#  HGB（1<100mg/L,2≥100mg/L）                    1
#  HGB（1<100mg/L,0≥100mg/L）                    1
# PLA2（0<659IU/L,1≥659IU/L）.1                  1
# PLA2（0<659IU/L,1≥659IU/L）                    1
# 脾大（1,是，0否）                                   1
# CRP                                          1
# TM(>5450,1;≤5450，0，正常范围5450±2140)pg/mL).1    1
# TM(>5450,1;≤5450，0，正常范围5450±2140)pg/mL)      1
# RDW1(0<15%,1≥15%.1                           1
# RDW1(0<15%,1≥15%                             1
# LDH                                          1
# SOD                                          1
# MCV(0<100fL,1≥100mfL)                        0
# dtype: int64
# Feature shape after encoding: (62, 30)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=TEST_SIZE,
    random_state=RANDOM_STATE,
    stratify=y
)

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

print("Train:", X_train.shape)
print("Test:", X_test.shape)
# Out:
# Train: (49, 30)
# Test: (13, 30)

# %%
model = LogisticRegression(
    penalty="l2",
    C=1.0,
    solver="liblinear",
    class_weight="balanced",
    random_state=RANDOM_STATE,
    max_iter=1000
)

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000, random_state=42,
#                    solver='liblinear')

# %%
y_pred = model.predict(X_test)
y_prob = model.predict_proba(X_test)[:, 1]

# %%
metrics = {
    "accuracy": accuracy_score(y_test, y_pred),
    "precision": precision_score(y_test, y_pred),
    "recall": recall_score(y_test, y_pred),
    "f1": f1_score(y_test, y_pred),
    "roc_auc": roc_auc_score(y_test, y_prob),
    "pr_auc": average_precision_score(y_test, y_prob)
}

metrics_df = pd.DataFrame(metrics, index=["RandomForest"])
metrics_df
# Out:
#               accuracy  precision  recall        f1  roc_auc   pr_auc
# RandomForest  0.923077   0.857143     1.0  0.923077  0.97619  0.97619

# %%
fpr, tpr, _ = roc_curve(y_test, y_prob)

plt.figure()
plt.plot(fpr, tpr, label=f"AUC = {metrics['roc_auc']:.3f}")
plt.plot([0, 1], [0, 1], "k--")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - Random Forest")
plt.legend()
plt.show()

# %%
precision, recall, _ = precision_recall_curve(y_test, y_prob)

plt.figure()
plt.plot(recall, precision, label=f"AP = {metrics['pr_auc']:.3f}")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve - Random Forest")
plt.legend()
plt.show()

# %%
feat_imp = pd.Series(
    np.abs(model.coef_[0]),
    index=X.columns
).sort_values(ascending=False)

plt.figure(figsize=(6, 8))
sns.barplot(x=feat_imp.head(20), y=feat_imp.head(20).index)
plt.title("Top 20 Feature Importances (RF)")
plt.xlabel("Importance")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_832/2590784391.py:10: UserWarning: Glyph 65288 (\N{FULLWIDTH LEFT PARENTHESIS}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_832/2590784391.py:10: UserWarning: Glyph 65289 (\N{FULLWIDTH RIGHT PARENTHESIS}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_832/2590784391.py:10: UserWarning: Glyph 65292 (\N{FULLWIDTH COMMA}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_832/2590784391.py:10: UserWarning: Glyph 27491 (\N{CJK UNIFIED IDEOGRAPH-6B63}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_832/2590784391.py:10: UserWarning: Glyph 24120 (\N{CJK UNIFIED IDEOGRAPH-5E38}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_832/2590784391.py:10: UserWarning: Glyph 33539 (\N{CJK UNIFIED IDEOGRAPH-8303}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_832/2590784391.py:10: UserWarning: Glyph 22260 (\N{CJK UNIFIED IDEOGRAPH-56F4}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_832/2590784391.py:10: UserWarning: Glyph 33026 (\N{CJK UNIFIED IDEOGRAPH-8102}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_832/2590784391.py:10: UserWarning: Glyph 34507 (\N{CJK UNIFIED IDEOGRAPH-86CB}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_832/2590784391.py:10: UserWarning: Glyph 30333 (\N{CJK UNIFIED IDEOGRAPH-767D}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_832/2590784391.py:10: UserWarning: Glyph 33086 (\N{CJK UNIFIED IDEOGRAPH-813E}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_832/2590784391.py:10: UserWarning: Glyph 22823 (\N{CJK UNIFIED IDEOGRAPH-5927}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_832/2590784391.py:10: UserWarning: Glyph 26159 (\N{CJK UNIFIED IDEOGRAPH-662F}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_832/2590784391.py:10: UserWarning: Glyph 21542 (\N{CJK UNIFIED IDEOGRAPH-5426}) missing from current font.
#   plt.tight_layout()
# /root/miniconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 65288 (\N{FULLWIDTH LEFT PARENTHESIS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/miniconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 65289 (\N{FULLWIDTH RIGHT PARENTHESIS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/miniconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 65292 (\N{FULLWIDTH COMMA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/miniconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 27491 (\N{CJK UNIFIED IDEOGRAPH-6B63}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/miniconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 24120 (\N{CJK UNIFIED IDEOGRAPH-5E38}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/miniconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 33539 (\N{CJK UNIFIED IDEOGRAPH-8303}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/miniconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 22260 (\N{CJK UNIFIED IDEOGRAPH-56F4}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/miniconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 33026 (\N{CJK UNIFIED IDEOGRAPH-8102}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/miniconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 34507 (\N{CJK UNIFIED IDEOGRAPH-86CB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/miniconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 30333 (\N{CJK UNIFIED IDEOGRAPH-767D}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/miniconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 33086 (\N{CJK UNIFIED IDEOGRAPH-813E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/miniconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 22823 (\N{CJK UNIFIED IDEOGRAPH-5927}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/miniconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 26159 (\N{CJK UNIFIED IDEOGRAPH-662F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/miniconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 21542 (\N{CJK UNIFIED IDEOGRAPH-5426}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
metrics_df.to_csv("../outputs/rf_metrics.csv")
feat_imp.to_csv("../outputs/rf_feature_importance.csv")

plt.savefig("../outputs/rf_feature_importance.png", dpi=300)

# %% [markdown]
# ## Summary
#
# - Random Forest baseline completed
# - PR-AUC suggests model performance under class imbalance
# - Top features identified for further analysis
#
# Next steps:
# - XGBoost
# - LightGBM
# - Threshold tuning
